# %% [markdown]
# # Ruteo Chile Suplementos (Santiago)

# %%
import googlemaps
import pandas as pd
import numpy as np

# %%
gmaps = googlemaps.Client(key ='AIzaSyAA8-cMgJm9HIe0aQT9aOclcGo-NfXHVmQ') #Llave mia

# %% [markdown]
# # Lectura de Datos

# %%
dataset='direcciones_locales.xlsx'
archivo = pd.read_excel(dataset)

# %%
archivo['Direccion'][0]
# Out:
# 'AV.J.ALLESSANDRI 20040 L BS103'

# %%
archivo
# Out:
#                   Nombre Local  \
# 0    MALL PLAZA SAN BERNARDO 1
# 1    MALL PLAZA SAN BERNARDO 2
# 2           JUMBO SAN BERNARDO
# 3            DUOC SAN BERNARDO
# 4             DUOC PLAZA OESTE
# 5             DUOC PLAZA NORTE
# 6           CIUDAD EMPRESARIAL
# 7    MALL BARRIO INDEPENDENCIA
# 8                  LA CISTERNA
# 9                LA CISTERNA 2
# 10    INTERMODAL LA CISTERNA 1
# 11    INTERMODAL LA CISTERNA 2
# 12    INTERMODAL LA CISTERNA 3
# 13    INTERMODAL LA CISTERNA 4
# 14                   EL PARRÓN
# 15              FLORIDA CENTER
# 16            FLORIDA CENTER 2
# 17            METRO BELLAVISTA
# 18           FLORIDA CENTER 4
# 19          METRO BELLAVISTA 2
# 20            PLAZA VESPUCIO 2
# 21             UDLA LA FLORIDA
# 22           PRINCIPE DE GALES
# 23               SIMÓN BOLÍVAR
# 24            MALL PLAZA EGAÑA
# 25             ALTO LAS CONDES
# 26                      ELGOLF
# 27             ESCUELA MILITAR
# 28             PORTAL LA REINA
# ...

# %%
gmaps.distance_matrix(str(archivo['Direccion'][0])+" "+str(archivo['Comuna'][0])+" "+str(archivo['Ciudad'][0]),str(archivo['Direccion'][134])+" "+str(archivo['Comuna'][134])+" "+str(archivo['Ciudad'][134]))
# Out:
# {'destination_addresses': ['Pío XI 1615, Vitacura, Región Metropolitana, Chile'],
#  'origin_addresses': ['San Bernardo, Santiago Metropolitan Region, Chile'],
#  'rows': [{'elements': [{'distance': {'text': '32.4 km', 'value': 32376},
#      'duration': {'text': '30 mins', 'value': 1786},
#      'status': 'OK'}]}],
#  'status': 'OK'}

# %%
# distancias=np.ones((archivo.shape[0],archivo.shape[0]))*9999999

# %%
# tiempos=np.ones((archivo.shape[0],archivo.shape[0]))*9999999

# %% [markdown]
# # Matriz de Distancia y Tiempo

# %%
# gmaps = googlemaps.Client(key ='AIzaSyAA8-cMgJm9HIe0aQT9aOclcGo-NfXHVmQ') #Llave mia

# for i in range(len(archivo)):
#     for j in range(len(archivo)):
#         try:
#             if i!=j:
#                 result = gmaps.distance_matrix(str(archivo['Direccion'][i])+str(archivo['Comuna'][i])+str(archivo['Ciudad'][i]),str(archivo['Direccion'][j])+str(archivo['Comuna'][j])+str(archivo['Ciudad'][j]))
#                 distancia=result['rows'][0]['elements'][0]['duration']['value']
#                 tiempo=result['rows'][0]['elements'][0]['distance']['value']
#                 distancias[i][j]=distancia
#                 tiempos[i][j]=tiempo
#                 np.save('distancia.npy',distancias)
#                 np.save('tiempos.npy',tiempos)
#         except:
#             print("\n consulta cae en= ",(i,j))
#             print(str(archivo['Direccion'][i])+str(archivo['Comuna'][i])+str(archivo['Ciudad'][i]),str(archivo['Direccion'][j])+str(archivo['Comuna'][j])+str(archivo['Ciudad'][j]))
# Out:
#  consulta cae en=  (0, 17)
# AV.J.ALLESSANDRI 20040 L BS103SAN BERNARDOSANTIAGO CABILDO 189 LOCAL 2LA FLORIDASANTIAGO
#
#  consulta cae en=  (0, 75)
# AV.J.ALLESSANDRI 20040 L BS103SAN BERNARDOSANTIAGO AV. RECOLETA 850 LOCAL 5RECOLETA SANTIAGO
#
#  consulta cae en=  (0, 78)
# AV.J.ALLESSANDRI 20040 L BS103SAN BERNARDOSANTIAGO AV. LIB.B.OHIGGINS 1350, LO 11SANTIAGOSANTIAGO
#
#  consulta cae en=  (0, 81)
# AV.J.ALLESSANDRI 20040 L BS103SAN BERNARDOSANTIAGO BANDERA 1050 LOCAL 7SANTIAGOSANTIAGO
#
#  consulta cae en=  (0, 82)
# AV.J.ALLESSANDRI 20040 L BS103SAN BERNARDOSANTIAGO PLAZA DE ARMAS 1000 LOCAL 2SANTIAGOSANTIAGO
#
#  consulta cae en=  (0, 83)
# AV.J.ALLESSANDRI 20040 L BS103SAN BERNARDOSANTIAGO CATEDRAL 1500 LOCAL 1SANTIAGOSANTIAGO
#
#  consulta cae en=  (0, 84)
# AV.J.ALLESSANDRI 20040 L BS103SAN BERNARDOSANTIAGO AV. LIB. BER. O'HIGGINS 278 LOCAL 2SANTIAGOSANTIAGO
#
#  consulta cae en=  (0, 113)
# ...

# %%
errores=[]
distancias = np.load('distancia.npy')
tiempos = np.load('tiempos.npy')
for i in range(len(distancias)):
    for j in range(len(distancias)):
        if i!=j:
            if distancias[i][j]==9999999.0:
                errores.append((i,j))

# %%
print(len(errores))
# Out:
# 0

# %%
gmaps = googlemaps.Client(key ='AIzaSyAA8-cMgJm9HIe0aQT9aOclcGo-NfXHVmQ') #Llave mia

for i,j in errores:
    try:
        result = gmaps.distance_matrix(str(archivo['Direccion'][i])+" "+str(archivo['Comuna'][i])+" "+str(archivo['Ciudad'][i]),str(archivo['Direccion'][j])+" "+str(archivo['Comuna'][j])+" "+str(archivo['Ciudad'][j]))
        distancia=result['rows'][0]['elements'][0]['duration']['value']
        tiempo=result['rows'][0]['elements'][0]['distance']['value']
        distancias[i][j]=distancia
        tiempos[i][j]=tiempo
        np.save('distancia.npy',distancias)
        np.save('tiempos.npy',tiempos)
    except:
        print("\n consulta cae en= ",(i,j))
        print(str(archivo['Direccion'][i])+" "+str(archivo['Comuna'][i])+" "+str(archivo['Ciudad'][i]),str(archivo['Direccion'][j])+" "+str(archivo['Comuna'][j])+" "+str(archivo['Ciudad'][j]))

# %%
gmaps = googlemaps.Client(key ='AIzaSyB9khgHxsgrKMW6WmHf4jKqAQRmO0h8vEI') #Llave mia

for i,j in errores:
    try:
        result = gmaps.distance_matrix(str(archivo['Direccion'][i])+" "+str(archivo['Comuna'][i])+" "+str(archivo['Ciudad'][i]),str(archivo['Direccion'][j])+" "+str(archivo['Comuna'][j])+" "+str(archivo['Ciudad'][j]))
        distancia=result['rows'][0]['elements'][0]['duration']['value']
        tiempo=result['rows'][0]['elements'][0]['distance']['value']
        distancias[i][j]=distancia
        tiempos[i][j]=tiempo
        np.save('distancia.npy',distancias)
        np.save('tiempos.npy',tiempos)
    except:
        print("\n consulta cae en= ",(i,j))
        print(str(archivo['Direccion'][i])+" "+str(archivo['Comuna'][i])+" "+str(archivo['Ciudad'][i]),str(archivo['Direccion'][j])+" "+str(archivo['Comuna'][j])+" "+str(archivo['Ciudad'][j]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0d8fb8d440c2> in <module>()
#       1 gmaps = googlemaps.Client(key ='AIzaSyB9khgHxsgrKMW6WmHf4jKqAQRmO0h8vEI') #Llave mia
#       2
# ----> 3 for i,j in errores:
#       4     try:
#       5         result = gmaps.distance_matrix(str(archivo['Direccion'][i])+" "+str(archivo['Comuna'][i])+" "+str(archivo['Ciudad'][i]),str(archivo['Direccion'][j])+" "+str(archivo['Comuna'][j])+" "+str(archivo['Ciudad'][j]))
#
# NameError: name 'errores' is not defined

# %%
gmaps = googlemaps.Client(key ='AIzaSyAA8-cMgJm9HIe0aQT9aOclcGo-NfXHVmQ') #Llave mia
i=1
result = gmaps.geocode(str(archivo['Direccion'][i])+str(archivo['Comuna'][i])+str(archivo['Ciudad'][i]))

# %%
lat=result[0]["geometry"]["location"]["lat"]
lon=result[0]["geometry"]["location"]["lng"]
print(lat,lon)
# Out:
# -33.6316638 -70.7103613

# %%
coordenadas=[]
for i in range(len(archivo)):
    coordenadas.append((0,0))
coordenadas=np.asarray(coordenadas).astype(float)

# %%
gmaps = googlemaps.Client(key ='AIzaSyAA8-cMgJm9HIe0aQT9aOclcGo-NfXHVmQ') #Llave mia

for i in range(len(archivo)):
    try:
        result = gmaps.geocode(str(archivo['Direccion'][i])+str(archivo['Comuna'][i])+str(archivo['Ciudad'][i]))
        print("\n consulta "+str(i)+" correcta")
        lat=result[0]["geometry"]["location"]["lat"]
        lon=result[0]["geometry"]["location"]["lng"]
        print("todo bien")
        coordenadas[i]=(lat,lon)
        np.save('coordenadas.npy',coordenadas)
    except:
        print("\n consulta cae en= ",i)
        print(str(archivo['Direccion'][i])+str(archivo['Comuna'][i])+str(archivo['Ciudad'][i]))
# Out:
#  consulta 0 correcta
# todo bien
#
#  consulta 1 correcta
# todo bien
#
#  consulta 2 correcta
# todo bien
#
#  consulta 3 correcta
# todo bien
#
#  consulta 4 correcta
# todo bien
#
#  consulta 5 correcta
# todo bien
#
#  consulta 6 correcta
# todo bien
#
#  consulta 7 correcta
# todo bien
#
#  consulta 8 correcta
# todo bien
#
#  consulta 9 correcta
# todo bien
#
#  consulta 10 correcta
# todo bien
#
#  consulta 11 correcta
# todo bien
#
#  consulta 12 correcta
# todo bien
#
#  consulta 13 correcta
# todo bien
#
#  consulta 14 correcta
# todo bien
#
#  consulta 15 correcta
# todo bien
#
#  consulta 16 correcta
# todo bien
#
#  consulta 17 correcta
# todo bien
#
#  consulta 18 correcta
# todo bien
#
#  consulta 19 correcta
# todo bien
#
#  consulta 20 correcta
# todo bien
#
#  consulta 21 correcta
# todo bien
#
#  consulta 22 correcta
# todo bien
#
#  consulta 23 correcta
# todo bien
#
#  consulta 24 correcta
# todo bien
#
#  consulta 25 correcta
# todo bien
#
# ...

# %%
coordenadas = np.load('coordenadas.npy')
coordenadas
# Out:
# array([[-33.6316638, -70.7103613],
#        [-33.6316638, -70.7103613],
#        [-33.633671 , -70.7092268],
#        [-33.5990142, -70.7053702],
#        [-33.5034955, -70.7383777],
#        [-33.3662205, -70.6784764],
#        [-33.3891362, -70.6182044],
#        [-33.424301 , -70.6534809],
#        [-33.4488897, -70.6692655],
#        [-33.5264495, -70.6613511],
#        [-33.5384435, -70.6637835],
#        [-33.5384435, -70.6637835],
#        [-33.5384435, -70.6637835],
#        [-33.5384435, -70.6637835],
#        [-33.4453173, -70.6506813],
#        [-33.5107421, -70.6064993],
#        [-33.5107421, -70.6064993],
#        [-33.5194969, -70.6009383],
#        [-33.5107421, -70.6064993],
#        [-33.5194969, -70.6009383],
#        [-33.5186331, -70.5995848],
#        [-33.521776 , -70.58357  ],
#        [-33.4390523, -70.5730136],
#        [-33.4457823, -70.5718992],
#        [-33.4524377, -70.5694704],
#        [-29.925434 , -71.2582214],
#        [-33.390873 , -70.546284 ],
# ...

# %%
errores_cord=[]
coordenadas = np.load('coordenadas.npy')
for i in range(len(coordenadas)):
    if coordenadas[i]==(0.0,0.0):
        errores_cord.append((i,j))
errores_cord
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-22b674260add> in <module>()
#       2 coordenadas = np.load('coordenadas.npy')
#       3 for i in range(len(coordenadas)):
# ----> 4     if coordenadas[i]==(0.0,0.0):
#       5         errores_cord.append((i,j))
#       6 errores_cord
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
